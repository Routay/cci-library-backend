# %% [markdown]
# # 🎓 Projet Final : Gestion de l'École Pythonique
#
# Félicitations pour être arrivé jusqu'ici ! Ce projet final va évaluer toutes les compétences que vous avez acquises durant ces 5 jours :
# - **Jour 1** : Variables, Listes, Chaînes de caractères
# - **Jour 2** : Conditions (if/else), Boucles (while/for)
# - **Jour 3** : Fonctions, Modularité
# - **Jour 4** : Dictionnaires, Gestion des erreurs (try/except)
# - **Jour 5** : Programmation Orientée Objet (Classes, Objets)
#
# ## Votre mission
# Vous allez construire une application interactive de gestion d'étudiants.
# Dans chaque cellule de code, vous trouverez des commentaires `# À COMPLÉTER`. Vous devez remplacer ces commentaires par le code Python approprié en vous aidant des indices fournis.
#
# Commençons par construire les fondations de notre application !

# %% [markdown]
# ## Étape 1 : La Classe Étudiant (Jour 5 - POO)
# Nous allons créer une classe `Etudiant` qui servira de modèle pour créer nos étudiants. Un étudiant a un nom, un âge et une note.
#
# **Instructions :**
# 1. Complétez la méthode `__init__` pour assigner les paramètres aux attributs de l'objet (utilisez `self`).
# 2. Complétez la méthode `afficher_infos` pour retourner une chaîne de caractères formatée (ex: "Nom: Alice, Âge: 20, Note: 15").

# %%
class Etudiant:
    def __init__(self, nom, age, note):
        # À COMPLÉTER : Assignez 'nom', 'age' et 'note' aux attributs de l'objet (ex: self.nom = nom)
        self.nom = nom
        self.age = age
        self.note = note
1
    def afficher_infos(self):
        # À COMPLÉTER : Retournez une chaîne de caractères qui combine les attributs
        # Exemple attendu : "Nom: Alice, Âge: 20, Note: 15"
        infos = f"Nom: {self.nom}, Âge: {self.age}, Note: {self.note}"
        return infos

Etudiant1 = Etudiant("Alice", 20, 15)
print(Etudiant1.afficher_infos())
# Out:
# Nom: Alice, Âge: 20, Note: 15

# %% [markdown]
# ## Étape 2 : La Classe Ecole (Jours 1, 3, 4, 5)
# Nous allons créer une classe `Ecole` qui va gérer une collection d'étudiants. Nous utiliserons un **dictionnaire** pour stocker les étudiants, où la clé sera le nom de l'étudiant.
#
# **Instructions :**
# 1. Dans `__init__`, initialisez un dictionnaire vide appelé `self.etudiants`.
# 2. Dans `ajouter_etudiant`, créez un objet `Etudiant` et ajoutez-le au dictionnaire `self.etudiants` avec le `nom` comme clé.
# 3. Dans `lister_etudiants`, utilisez une boucle (`for`) pour parcourir et afficher les infos de chaque étudiant du dictionnaire.
# 4. Dans `moyenne_notes`, parcourez le dictionnaire, additionnez les notes et calculez la moyenne.

# %%
class Ecole:
    def __init__(self):
        # À COMPLÉTER : Créez un dictionnaire vide pour stocker les étudiants
        self.etudiants = {}
        pass

    def ajouter_etudiant(self, nom, age, note):
        nouvelle_Etudiant = Etudiant(nom, age, note)
        self.etudiants[nom] = nouvelle_Etudiant
        pass

    def lister_etudiants(self):
        print("--- Liste des étudiants ---")
        # À COMPLÉTER : Utilisez une boucle for pour parcourir les valeurs du dictionnaire self.etudiants
        for Etudiant in self.etudiants.values():
        # et appelez la méthode afficher_infos() de chaque étudiant
          print(Etudiant.afficher_infos())
        print("---------------------------")

    def moyenne_notes(self):
        if len(self.etudiants) == 0:
            return 0.0

        total = 0
        # À COMPLÉTER : Parcourez le dictionnaire, additionnez les notes dans 'total'
        for Etudiant in self.etudiants.values():
          total += float(Etudiant.note)
        # À COMPLÉTER : Retournez la moyenne (total divisé par le nombre d'étudiants)
          return total /len(self.etudiants)

# %% [markdown]
# ## Étape 3 : Le Menu Interactif (Jours 2 et 4)
# Maintenant, créons la fonction principale qui fera tourner l'application. Elle affichera un menu et réagira aux choix de l'utilisateur.
#
# **Instructions :**
# 1. Complétez les conditions `if/elif` pour appeler les bonnes méthodes de la classe `Ecole`.
# 2. Pour ajouter un étudiant, demandez son nom, son âge et sa note avec `input()`. Pensez à convertir l'âge et la note en entiers (`int()`).
# 3. Utilisez un bloc `try/except` pour gérer l'erreur si l'utilisateur tape du texte au lieu d'un nombre pour l'âge ou la note.
# 4. La boucle `while` doit s'arrêter si l'utilisateur tape '4'.

# %%
def lancer_application():
    mon_ecole = Ecole()
    print("Bienvenue dans le système de gestion de l'école !")

    while True:
        print("\n1. Ajouter un étudiant")
        print("2. Lister les étudiants")
        print("3. Afficher la moyenne des notes")
        print("4. Quitter")

        choix = input("Votre choix : ")

        if choix == '1':
            nom = input("Entrez le nom de l'étudiant : ")
            try:
                # À COMPLÉTER : Demandez l'âge et la note, et convertissez-les en int()
                age = int(input("Entrez l'age de l'etudiant:"))
                note = float(input("Entrez la note de l'etudiant:"))

                # À COMPLÉTER : Appelez la méthode de mon_ecole pour ajouter cet étudiant
                mon_ecole.ajouter_etudiant(nom, age, note)
                print(f"{nom} a été ajouté avec succès !")
            except ValueError:
                # À COMPLÉTER : Affichez un message d'erreur si la conversion en int a échoué
                print("Erreur: l'age et la note doivent etre des nombres entiers")

        elif choix == '2':
            # À COMPLÉTER : Appelez la méthode pour lister les étudiants
            mon_ecole.lister_etudiants()
            pass

        elif choix == '3':
            # À COMPLÉTER : Récupérez la moyenne et affichez-la
            moyenne = mon_ecole. moyenne_notes()
            print(f"La moyenne générale de l'école est de : {moyenne:.2f}/20")
            pass

        elif choix == '4':
            print("Au revoir !")
            # À COMPLÉTER : Utilisez le mot-clé approprié pour casser la boucle while
            break
            pass

        else:
            print("Choix invalide. Veuillez entrer un nombre entre 1 et 4.")

# %% [markdown]
# ## Étape 4 : Validation de votre code
# Avant de lancer l'application interactive, exécutez cette cellule. Elle va tester si vous avez bien écrit le code. Si tout est bon, exécutez la cellule de l'Étape 5 pour jouer avec votre application !

# %%
def tester_code():
    try:
        # Test Etudiant
        e = Etudiant("Test", 20, 15)
        assert e.nom == "Test", "L'attribut nom n'est pas assigné"
        assert e.age == 20, "L'attribut age n'est pas assigné"
        assert e.note == 15, "L'attribut note n'est pas assigné"
        assert "Test" in e.afficher_infos() and "15" in e.afficher_infos(), "La méthode afficher_infos est incomplète"

        # Test Ecole
        ecole = Ecole()
        assert isinstance(ecole.etudiants, dict), "self.etudiants doit être un dictionnaire"
        ecole.ajouter_etudiant("Alice", 20, 15)
        ecole.ajouter_etudiant("Bob", 22, 10)
        assert len(ecole.etudiants) == 2, "Les étudiants ne sont pas ajoutés au dictionnaire"
        assert "Alice" in ecole.etudiants, "La clé doit être le nom"

        # Test Moyenne
        m = ecole.moyenne_notes()
        assert m == 12.5, "Le calcul de la moyenne est incorrect"

        print("✅ BRAVO ! Toutes les étapes 1, 2 et 3 sont correctes. Votre application est fonctionnelle !")
        print("Vous pouvez maintenant exécuter la cellule ci-dessous pour lancer le menu.")
    except Exception as e:
        print(f"❌ Oups, il y a une erreur : {e}")
        print("Corrigez votre code dans les cellules du haut, puis relancez ce test.")

tester_code()

# %% [markdown]
# ## Étape 5 : Lancement de l'application !
# Exécutez cette cellule pour lancer le menu interactif. Amusez-vous à ajouter des étudiants, afficher la liste et calculer la moyenne !

# %%
lancer_application()
# Out:
# Bienvenue dans le système de gestion de l'école !
#
# 1. Ajouter un étudiant
# 2. Lister les étudiants
# 3. Afficher la moyenne des notes
# 4. Quitter
# Votre choix : 1
